# %%
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout
from tensorflow.keras.optimizers import Adam
import os

# %%
# Set data paths
d_train='/content/drive/MyDrive/tmp_sat/data_train'
d_val='/content/drive/MyDrive/tmp_sat/data_val'
d_test='/content/drive/MyDrive/tmp_sat/data_test'

# %%
# 1. Data Preparation and Augmentation
train_datagen = ImageDataGenerator(
    rescale=1./255,
    shear_range=0.2,
    zoom_range=0.2,
    horizontal_flip=True
)

test_datagen = ImageDataGenerator(rescale=1./255)

train_generator = train_datagen.flow_from_directory(
    d_train,
    target_size=(150, 150),  # Adjust target size as needed
    batch_size=30,
    class_mode='categorical'  # or 'categorical' if more than 2 classes
)

validation_generator = test_datagen.flow_from_directory(
    d_val,
    target_size=(150, 150),
    batch_size=30,
    class_mode='categorical'
)

test_generator = test_datagen.flow_from_directory(
    d_test,
    target_size=(150, 150),
    batch_size=30,
    class_mode='categorical'
)
# Out:
# Found 300 images belonging to 3 classes.
# Found 300 images belonging to 3 classes.
# Found 300 images belonging to 3 classes.

# %%
# 2. Build the CNN Model
model = Sequential([
    Conv2D(32, (3, 3), activation='relu', input_shape=(150, 150, 3)),
    MaxPooling2D(2, 2),
    Conv2D(64, (3, 3), activation='relu'),
    MaxPooling2D(2, 2),
    Conv2D(128, (3, 3), activation='relu'),
    MaxPooling2D(2, 2),
    Flatten(),
    Dense(512, activation='relu'),
    Dropout(0.5),
    Dense(3, activation='sigmoid')  # binary classification
])
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
# 3. Compile the Model
model.compile(optimizer=Adam(learning_rate=0.001),
              loss='binary_crossentropy',  # or 'categorical_crossentropy'
              metrics=['accuracy'])

# %%
# 4. Train the Model
history = model.fit(
    train_generator,
    steps_per_epoch=train_generator.samples // train_generator.batch_size,
    epochs=10,  # Adjust number of epochs
    validation_data=validation_generator,
    validation_steps=validation_generator.samples // validation_generator.batch_size
)
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/10
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 147s 15s/step - accuracy: 0.5163 - loss: 0.7340 - val_accuracy: 0.6800 - val_loss: 0.3222
# Epoch 2/10
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 84s 3s/step - accuracy: 0.7129 - loss: 0.3407 - val_accuracy: 0.6833 - val_loss: 0.3069
# Epoch 3/10
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 40s 3s/step - accuracy: 0.6739 - loss: 0.3489 - val_accuracy: 0.8433 - val_loss: 0.2979
# Epoch 4/10
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 31s 3s/step - accuracy: 0.7068 - loss: 0.3108 - val_accuracy: 0.8200 - val_loss: 0.2866
# Epoch 5/10
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 34s 2s/step - accuracy: 0.7446 - loss: 0.2925 - val_accuracy: 0.8167 - val_loss: 0.2773
# Epoch 6/10
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 41s 2s/step - accuracy: 0.8008 - loss: 0.2669 - val_accuracy: 0.8600 - val_loss: 0.2057
# Epoch 7/10
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 25s 2s/step - accuracy: 0.8958 - loss: 0.2123 - val_accuracy: 0.8500 - val_loss: 0.2203
# Epoch 8/10
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 41s 3s/step - accuracy: 0.8368 - loss: 0.2282 - val_accuracy: 0.9033 - val_loss: 0.1734
# Epoch 9/10
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 41s 3s/step - accuracy: 0.8818 - loss: 0.2100 - val_accuracy: 0.8000 - val_loss: 0.2678
# Epoch 10/10
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 31s 3s/step - accuracy: 0.8054 - loss: 0.2675 - val_accuracy: 0.7167 - val_loss: 0.2997

# %%
# 5. Evaluate the Model (Optional)
loss, accuracy = model.evaluate(validation_generator)
print(f"Test Loss: {loss:.4f}, Test Accuracy: {accuracy:.4f}")
# Out:
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 6s 567ms/step - accuracy: 0.7046 - loss: 0.3053
# Test Loss: 0.2997, Test Accuracy: 0.7167

# %%
# 5. Evaluate the Model (Optional)
loss, accuracy = model.evaluate(test_generator)
print(f"Test Loss: {loss:.4f}, Test Accuracy: {accuracy:.4f}")
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 48s 5s/step - accuracy: 0.7658 - loss: 0.2856
# Test Loss: 0.2999, Test Accuracy: 0.7367

# %%
# 6. Save the model (Optional)
model.save('satellite_classifier.h5') #saves the model.
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-d6e242a9b630> in <cell line: 0>()
#       1 # 6. Save the model (Optional)
# ----> 2 model.save('satellite_classifier.h5') #saves the model.
#
# NameError: name 'model' is not defined

# %%
# 7. Load model for predictions (Optional)
# loaded_model = tf.keras.models.load_model('satellite_classifier.h5')
# predictions = loaded_model.predict(validation_generator)
